# %% [markdown]
# - **Este documento serve para auxiliar pessoas que estão aprendendo a utilizar python e o pandas para analise de dados**
# - **Para executar cada comando basta remover o # que se encontra antes de cada comando**

# %%
import pandas as pd
import numpy as np
import re #(regular expression)

pd.options.display.max_rows = 800
df = pd.read_csv("pokemon_data.csv")
df
# Out:
#        #                       Name    Type 1    Type 2   HP  Attack  Defense  \
# 0      1                  Bulbasaur     Grass    Poison   45      49       49
# 1      2                    Ivysaur     Grass    Poison   60      62       63
# 2      3                   Venusaur     Grass    Poison   80      82       83
# 3      3      VenusaurMega Venusaur     Grass    Poison   80     100      123
# 4      4                 Charmander      Fire       NaN   39      52       43
# 5      5                 Charmeleon      Fire       NaN   58      64       58
# 6      6                  Charizard      Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X      Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y      Fire    Flying   78     104       78
# 9      7                   Squirtle     Water       NaN   44      48       65
# 10     8                  Wartortle     Water       NaN   59      63       80
# ...

# %%
print(df.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df[['Name','Attack']]
# Out:
#                           Name  Attack
# 0                    Bulbasaur      49
# 1                      Ivysaur      62
# 2                     Venusaur      82
# 3        VenusaurMega Venusaur     100
# 4                   Charmander      52
# 5                   Charmeleon      64
# 6                    Charizard      84
# 7    CharizardMega Charizard X     130
# 8    CharizardMega Charizard Y     104
# 9                     Squirtle      48
# 10                   Wartortle      63
# 11                   Blastoise      83
# 12     BlastoiseMega Blastoise     103
# 13                    Caterpie      30
# 14                     Metapod      20
# 15                  Butterfree      45
# 16                      Weedle      35
# 17                      Kakuna      25
# 18                    Beedrill      90
# 19       BeedrillMega Beedrill     150
# 20                      Pidgey      45
# 21                   Pidgeotto      60
# 22                     Pidgeot      80
# ...

# %%
df.head(4)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
df.iloc[1:8]
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
#
#    Sp. Def  Speed  Generation  Legendary
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
# 5       65     80           1      False
# 6       85    100           1      False
# 7       85    100           1      False

# %%
df.iloc[6,1]
# Out:
# 'Charizard'

# %%
df.loc[df['Name'] == 'Charizard']
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 6  6  Charizard   Fire  Flying  78      84       78      109       85    100
#
#    Generation  Legendary
# 6           1      False

# %%
df.loc[df['Type 1'] == 'Fire']
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %%
for index, row in df.iterrows():
    #funcao soma
    print(index,row)
# Out:
# 0 #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object
# 1 #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object
# 2 #                    3
# Name          Venusaur
# Type 1           Grass
# Type 2          Poison
# HP                  80
# Attack              82
# Defense             83
# Sp. Atk            100
# Sp. Def            100
# Speed               80
# Generation           1
# Legendary        False
# Name: 2, dtype: object
# ...

# %%
for index, row in df.iterrows():
    print(index,row['Name'] > 50 )
# Out:
# 0 False
# 1 False
# 2 False
# 3 False
# 4 False
# 5 False
# 6 True
# 7 False
# 8 False
# 9 False
# 10 False
# 11 False
# 12 False
# 13 False
# 14 False
# 15 False
# 16 False
# 17 False
# 18 False
# 19 False
# 20 False
# 21 False
# 22 False
# 23 False
# 24 False
# 25 False
# 26 False
# 27 False
# 28 False
# 29 False
# 30 False
# 31 False
# 32 False
# 33 False
# 34 False
# 35 False
# 36 False
# 37 False
# 38 False
# 39 False
# 40 False
# 41 False
# 42 False
# 43 False
# 44 False
# 45 False
# 46 False
# 47 False
# 48 False
# 49 False
# 50 False
# 51 False
# 52 False
# 53 False
# 54 False
# 55 False
# 56 False
# 57 False
# 58 False
# 59 False
# 60 False
# 61 False
# 62 False
# 63 False
# 64 False
# 65 False
# 66 False
# 67 False
# 68 False
# 69 False
# 70 False
# 71 False
# 72 False
# 73 False
# 74 False
# 75 False
# 76 False
# 77 False
# 78 False
# 79 False
# 80 False
# 81 False
# 82 False
# 83 False
# 84 False
# 85 False
# 86 False
# 87 False
# 88 False
# 89 False
# 90 False
# ...

# %% [markdown]
# - **Lendo os dados com Pandas**

# %%
### Leitura do cabeçalho
#print(df.columns)                          # Mostra o cabeçalho da base de dados


### Leitura de cada coluna
#print (df[['Name','Type 1']])              # Mostra colunas selecionadas pelo nome


### Leitura de cada linha
#print(df.head(4))                          # Mostra as 4 primeiras linhas de dados
#print(df.iloc[1:8])                        # Mostra as 4 primeiras linhas de dados


### Leitura de um local especifico, usando uma coordenada
#print(df.iloc[6,1])                        # Verifica a posição da 6 linha, 2 coluna e retorna o que há nela(Charizard)


### Leitura de um local especifico, usando um index    
#print(df.loc[df['Name'] == 'Charizard'])   # Procurar dados especificos, baseado em valores numericos ou textuais
#print(df.loc[df['Type 1'] == 'Water'])   


### Navegar por todas as linhas
#for index, row in df.iterrows():
#    print(index,row)


### Navegar por todas as linhas, usando um index    
#for index, row in df.iterrows():
#    print(index,row['Name'])


### Navegar por todas as linhas, comparando com um index    
#for index, row in df.iterrows():
#    print(index,row['Name'] == 'Charizard')

# %%
df
# Out:
#        #                       Name    Type 1    Type 2   HP  Attack  Defense  \
# 0      1                  Bulbasaur     Grass    Poison   45      49       49
# 1      2                    Ivysaur     Grass    Poison   60      62       63
# 2      3                   Venusaur     Grass    Poison   80      82       83
# 3      3      VenusaurMega Venusaur     Grass    Poison   80     100      123
# 4      4                 Charmander      Fire       NaN   39      52       43
# 5      5                 Charmeleon      Fire       NaN   58      64       58
# 6      6                  Charizard      Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X      Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y      Fire    Flying   78     104       78
# 9      7                   Squirtle     Water       NaN   44      48       65
# 10     8                  Wartortle     Water       NaN   59      63       80
# ...

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.sort_values('HP', ascending=False)
# Out:
#        #                       Name    Type 1    Type 2   HP  Attack  Defense  \
# 261  242                    Blissey    Normal       NaN  255      10       10
# 121  113                    Chansey    Normal       NaN  250       5        5
# 217  202                  Wobbuffet   Psychic       NaN  190      33       58
# 351  321                    Wailord     Water       NaN  170      90       45
# 655  594                  Alomomola     Water       NaN  165      75       80
# 155  143                    Snorlax    Normal       NaN  160     110       65
# 473  426                   Drifblim     Ghost    Flying  150      80       44
# 313  289                    Slaking    Normal       NaN  150     160      100
# 544  487      GiratinaAltered Forme     Ghost    Dragon  150     100      120
# 545  487       GiratinaOrigin Forme     Ghost    Dragon  150     120      100
# 321  297                   Hariyama  Fighting       NaN  144     120       60
# ...

# %%
#df.describe()                                     # Retorna uma estatistica resumida dos dados que foram inseridos
 
    
#df.sort_values('HP')                              # Ordena os dados de acordo com o index


#df.sort_values('HP', ascending=False)             # Ordena os dados de acordo com o index, crescente ou decrescente


#df.sort_values(['HP', 'Name'], ascending=[0,1])   # Ordena os dados de acordo com o index, HP=crescente Tipo=decrescente

# %%
df
# Out:
#        #                       Name    Type 1    Type 2   HP  Attack  Defense  \
# 0      1                  Bulbasaur     Grass    Poison   45      49       49
# 1      2                    Ivysaur     Grass    Poison   60      62       63
# 2      3                   Venusaur     Grass    Poison   80      82       83
# 3      3      VenusaurMega Venusaur     Grass    Poison   80     100      123
# 4      4                 Charmander      Fire       NaN   39      52       43
# 5      5                 Charmeleon      Fire       NaN   58      64       58
# 6      6                  Charizard      Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X      Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y      Fire    Flying   78     104       78
# 9      7                   Squirtle     Water       NaN   44      48       65
# 10     8                  Wartortle     Water       NaN   59      63       80
# ...

# %%
### Criando uma coluna que soma todos os status dos pokemons
#df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']
#df.head(1)


###Colocando a coluna nova em um posicao escolhida
#colunas = list(df.columns.values)
#df = df[colunas[0:9] + [colunas[-1]] + colunas[10:12]]


### Excluindo uma coluna espefica
#df.drop(columns=['Total'])

# %%
df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']

# %%
df
# Out:
#        #                       Name    Type 1    Type 2   HP  Attack  Defense  \
# 0      1                  Bulbasaur     Grass    Poison   45      49       49
# 1      2                    Ivysaur     Grass    Poison   60      62       63
# 2      3                   Venusaur     Grass    Poison   80      82       83
# 3      3      VenusaurMega Venusaur     Grass    Poison   80     100      123
# 4      4                 Charmander      Fire       NaN   39      52       43
# 5      5                 Charmeleon      Fire       NaN   58      64       58
# 6      6                  Charizard      Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X      Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y      Fire    Flying   78     104       78
# 9      7                   Squirtle     Water       NaN   44      48       65
# 10     8                  Wartortle     Water       NaN   59      63       80
# ...

# %%
###Salvando as modificações em formato csv
#df.to_csv('pokemon_modificado.csv', index=False)


###Salvando as modificações em formato excel
#df.to_excel('pokemon_modificado.xlsx', index=False)


###Salvando as modificações em formato text
#df.to_csv('pokemon_modificado.txt', index=False, sep='\t')

# %% [markdown]
# - **Filtrando dados**

# %%
### Podemos procurar os dois tipos ao mesmo tempo
#df.loc[(df['Type 1'] == 'Fire') & (df['Type 2'] == 'Water')]


### Podemos procurar pokemons de tipos especificos
#df.loc[(df['Type 1'] == 'Fire') | (df['Type 2'] == 'Water')]


### Podemos procurar o melhor ataque em um pokemon de fogo
#df_fogo = df.loc[(df['Type 1'] == 'Fire')]
#df_fogo.sort_values('Attack', ascending=False)


### Encontrando pokemons que contem MEGA evolução
#df.loc[df['Name'].str.contains('Mega')]


### Removendo pokemons que contem MEGA evolução, usando ~ para dizer que nao queremos essa condição
#df.loc[~df['Name'].str.contains('Mega')]


### Estamos procurando pokemons que contenham 'ch' no inicio de seus nomes, a biblioteca re(regular expression) e flags para ignorar a diferença entre letras maiuscilas e minusculas
#df.loc[df['Name'].str.contains('^mew[a-z]*', flags=re.I, regex=True) ]

# %%
df.loc[(df['Type 1'] == 'Fire') & (df['Type 2'] == 'Water')]
# Out:
#        #       Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 799  721  Volcanion   Fire  Water  80     110      120      130       90
#
#      Speed  Generation  Legendary  Total
# 799     70           6       True    600

# %%
df.loc[df['Name'].str.contains('Mega')]
# Out:
#        #                       Name    Type 1    Type 2   HP  Attack  Defense  \
# 3      3      VenusaurMega Venusaur     Grass    Poison   80     100      123
# 7      6  CharizardMega Charizard X      Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y      Fire    Flying   78     104       78
# 12     9    BlastoiseMega Blastoise     Water       NaN   79     103      120
# 19    15      BeedrillMega Beedrill       Bug    Poison   65     150       40
# 23    18        PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 71    65      AlakazamMega Alakazam   Psychic       NaN   55      50       65
# 87    80        SlowbroMega Slowbro     Water   Psychic   95      75      180
# 102   94          GengarMega Gengar     Ghost    Poison   60      65       80
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN  105     125      100
# 137  127          PinsirMega Pinsir       Bug    Flying   65     155      120
# ...

# %%
df.loc[~df['Name'].str.contains('Mega')]
# Out:
#        #                      Name    Type 1    Type 2   HP  Attack  Defense  \
# 0      1                 Bulbasaur     Grass    Poison   45      49       49
# 1      2                   Ivysaur     Grass    Poison   60      62       63
# 2      3                  Venusaur     Grass    Poison   80      82       83
# 4      4                Charmander      Fire       NaN   39      52       43
# 5      5                Charmeleon      Fire       NaN   58      64       58
# 6      6                 Charizard      Fire    Flying   78      84       78
# 9      7                  Squirtle     Water       NaN   44      48       65
# 10     8                 Wartortle     Water       NaN   59      63       80
# 11     9                 Blastoise     Water       NaN   79      83      100
# 13    10                  Caterpie       Bug       NaN   45      30       35
# 14    11                   Metapod       Bug       NaN   50      20       55
# ...

# %% [markdown]
# - **Mudanças Condicionais**

# %%
### Podemos mudar o tipo de um pokemon, subistituindo o valor "Fire" por "Flamejante", caso a condição seja verdadeira
#df.loc[df['Type 1'] == 'Fire', 'Type 1'] = 'Flamejante'
#df


### Depois podemos mudar de volta caso queira
#df.loc[df['Type 1'] == 'Flamejante', 'Type 1'] = 'Fire'


### Assim teremos a condição, caso o pokemon seja do tipo fogo ele será lendario
#df.loc[df['Type 1'] == 'Fire', 'Legendary'] = True


### Pode ser mudado mais de uma valor baseado em uma condição
#df.loc[df['Total'] > 500,['Generation', 'Legendary']] = ['TESTE 1', 'TESTE 2']

# %% [markdown]
# - **Groupby**

# %%
### Verificamos qual o tipo de pokemons tem as maiores defesas, agrupando a media de suas defesas
#df.groupby(['Type 1']).mean().sort_values('Defense', ascending=False)  #Assim encontramos que os pokemons do tipo aço tem a maior defesa


### Podemos verificar quando pokemons existem de cada Tipo
#df.groupby(['Type 1']).count()['#']

# %%
df.groupby(['Type 1']).mean().sort_values('Defense', ascending=False)
# Out:
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Steel     442.851852  65.222222   92.703704  126.370370  67.518519  80.629630
# Rock      392.727273  65.363636   92.863636  100.795455  63.340909  75.477273
# Dragon    474.375000  83.312500  112.125000   86.375000  96.843750  88.843750
# Ground    356.281250  73.781250   95.750000   84.843750  56.468750  62.750000
# Ghost     486.500000  64.437500   73.781250   81.187500  79.343750  76.468750
# Water     303.089286  72.062500   74.151786   72.946429  74.812500  70.517857
# Ice       423.541667  72.000000   72.750000   71.416667  77.541667  76.291667
# Grass     344.871429  67.271429   73.214286   70.800000  77.500000  70.428571
# Bug       334.492754  56.884058   70.971014   70.724638  53.869565  64.797101
# Dark      461.354839  66.806452   88.387097   70.225806  74.645161  69.516129
# Poison    251.785714  67.250000   74.678571   68.821429  60.428571  64.392857
# ...

# %%
df.groupby(['Type 1']).count()['#']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: #, dtype: int64

# %% [markdown]
# - ***Operação com o dataset***

# %%
### Procurando os pokemons com maiores ataques de acordo com seu Tipo 1. Os lendarios foram removidos

#pd.options.display.max_rows = 800

#df_sem_lendario = df.loc[~df['Legendary'] == True]

#df_sem_lendario.loc[df_sem_lendario.groupby('Type 1')['Attack'].idxmax()]

# %%
### Procurando os pokemons com maiores defesas de acordo com seu Tipo 1. Os lendarios foram removidos

#df_sem_lendario = df.loc[~df['Legendary'] == True]

#df_sem_lendario.loc[df_sem_lendario.groupby('Type 1')['Defense'].idxmax()]

# %%
### Procurando os pokemons com maiores proporções de Combate. Os lendarios foram removidos 

#pd.options.display.max_rows = 800

#df_sem_lendario = df.loc[~df['Legendary'] == True]

#df_sem_lendario['CP'] = (np.sqrt(df['HP']) * df_sem_lendario['Attack'] * np.sqrt(df_sem_lendario['Defense'])) /10

#df_sem_lendario.sort_values('CP', ascending=False)

# %%
### Procurando os pokemons com maiores proporções de Combate. 

#pd.options.display.max_rows = 800

#df['CP'] = (np.sqrt(df['HP']) * df['Attack'] * np.sqrt(df['Defense'])) /10

#df.sort_values('CP', ascending=False)
